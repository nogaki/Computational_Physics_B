# %% [markdown]
# **for文とprint文**

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **for文と総和**

# %%
sum = 0
for i in range(10):
  sum = sum + (i+1)

print(sum)
# Out:
# 55

# %%
sum = 0
for i in range(3):
  for j in range(5):
    sum = sum + (i+1)*(j+1)

print(sum)
# Out:
# 90

# %% [markdown]
# **bool型**

# %%
10 > 5
# Out:
# True

# %%
10 == 2
# Out:
# False

# %%
True or False
# Out:
# True

# %% [markdown]
# **if文**

# %%
n = 5
m = 10
if n%2 == 0 and m%2 == 0:
  print("n and m are even number!")
else:
  print("n or m is odd number.")
# Out:
# n or m is odd number.

# %%
n = 5
m = 10
if n%2 == 0 or m%2 == 0:
  print("n or m is even number!")
else:
  print("n and m are odd number.")
# Out:
# n or m is even number!

# %%
for i in range(10):
  if i%2 == 0:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# **while文**

# %%
n = 2
while n < 100:
  n *= 2

print(n)
# Out:
# 128
